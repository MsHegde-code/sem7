# %%
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.mixture import GaussianMixture
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn import metrics
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

iris = load_iris()
x = pd.DataFrame(iris.data,columns=["sepal_length","sepal_width","petal_length","petal_width"])
y = pd.DataFrame(iris.target,columns=["target"])

colormap = np.array(["red","lime","black"])
plt.figure(figsize=(14,5))

plt.subplot(1,2,1)
plt.scatter(x.sepal_length,x.sepal_width,c=colormap[y.target])
plt.title("sepal plot")

plt.subplot(1,2,2)
plt.scatter(x.petal_length,x.petal_width,c=colormap[y.target])
plt.title("petal plot")
# Out:
# Text(0.5, 1.0, 'petal plot')

# %%
model1 = KMeans(n_clusters=3)
model1.fit(x)
print("KMeans accuracy:",metrics.accuracy_score(model1.labels_,y.target))
print("KMeans confusion Matrix:\n",metrics.confusion_matrix(model1.labels_,y.target))

plt.subplot(1,2,1)
plt.scatter(x.petal_length, x.petal_width, c=colormap[y.target],s=40)
plt.title("real cluster")

plt.subplot(1,2,2)
plt.scatter(x.petal_length, x.petal_width, c=colormap[model1.labels_],s=40)
plt.title("KM cluster")

plt.show()
# Out:
# KMeans accuracy: 0.24
# KMeans confusion Matrix:
#  [[ 0 48 14]
#  [50  0  0]
#  [ 0  2 36]]

# %%
scaler = StandardScaler()
scaler.fit(x)
xsa = scaler.transform(x)
xs = pd.DataFrame(xsa, columns=x.columns)

# Fit Gaussian Mixture Model
gmm = GaussianMixture(n_components=3)
gmm.fit(xs)
gmm_labels = gmm.predict(xs)
print(metrics.accuracy_score(gmm_labels,y.target))
print(metrics.confusion_matrix(gmm_labels,y.target))

# Plot the Models Classifications (GMM)
plt.scatter(x.petal_length, x.petal_width, c=colormap[gmm_labels], s=40)
plt.title('GMM Clustering')
plt.show()
# Out:
# 0.9666666666666667
# [[50  0  0]
#  [ 0 45  0]
#  [ 0  5 50]]
